# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'E:/Python/data/notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# 将数据转换成适合tensorflow使用的形状：
#
# - cube
# - one-hot编码形式

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
    dataset = dataset.reshape(
       (-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %%
batch_size = 16 # 每个批次样本大小
patch_size = 5
depth = 16 # depth的大小应该与batch_size的大小一样
num_hidden = 64
graph = tf.Graph()

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    # 第一层权重的维度5*5*1*16，
    # 图像的灰度（厚度）为1，批量样本个数为16，
    # 滤波器的大小为5*5，故需要16个滤波器
    layer1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    
    layer2_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    # tf.nn.conv2d()中stride参数为[1, 2, 2, 1]，stride[0]和stride[3]分别针对批量样本
    # 、channel的步长，中间两个参数则是针对图像的长和宽扫描时的步长
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("初始化变量...")
    for step in range(num_steps):
        # Pick an offset within the training data, which has been randomized.
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        # Prepare a dictionary telling the session where to feed the minibatch.
        # The key of the dictionary is the placeholder node of the graph to be fed,
        # and the value is the numpy array to feed to it.
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch 准确率: %.1f%%" % accuracy(predictions, batch_labels))
            print("验证集准确率: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
    print("测试集准确率: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-6-1286133431d5>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# 初始化变量...
# Minibatch loss at step 0: 3.348956
# Minibatch 准确率: 6.2%
# 验证集准确率: 10.4%
# Minibatch loss at step 500: 0.517610
# Minibatch 准确率: 87.5%
# 验证集准确率: 81.5%
# Minibatch loss at step 1000: 0.411721
# Minibatch 准确率: 81.2%
# 验证集准确率: 82.8%
# Minibatch loss at step 1500: 0.497363
# Minibatch 准确率: 87.5%
# 验证集准确率: 84.2%
# Minibatch loss at step 2000: 0.205481
# Minibatch 准确率: 93.8%
# 验证集准确率: 85.2%
# Minibatch loss at step 2500: 0.271119
# Minibatch 准确率: 100.0%
# 验证集准确率: 85.4%
# Minibatch loss at step 3000: 0.472033
# Minibatch 准确率: 81.2%
# 验证集准确率: 85.5%
# 测试集准确率: 92.0%

# %% [markdown]
# # 问题 1
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (nn.max_pool()) of stride 2 and kernel size 2.

# %%
batch_size = 16 # 每个批次样本大小
patch_size = 5
depth = 16 # depth的大小应该与batch_size的大小一样
num_hidden = 64
graph = tf.Graph()

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    
    layer2_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        
        conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        
        shape = pool.get_shape().as_list()
        reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("初始化变量...")
    for step in range(num_steps):
        # Pick an offset within the training data, which has been randomized.
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        # Prepare a dictionary telling the session where to feed the minibatch.
        # The key of the dictionary is the placeholder node of the graph to be fed,
        # and the value is the numpy array to feed to it.
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch 准确率: %.1f%%" % accuracy(predictions, batch_labels))
            print("验证集准确率: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
    print("测试集准确率: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-8-1286133431d5>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# 初始化变量...
# Minibatch loss at step 0: 3.947931
# Minibatch 准确率: 6.2%
# 验证集准确率: 13.6%
# Minibatch loss at step 500: 0.337004
# Minibatch 准确率: 87.5%
# 验证集准确率: 81.0%
# Minibatch loss at step 1000: 0.296769
# Minibatch 准确率: 87.5%
# 验证集准确率: 82.8%
# Minibatch loss at step 1500: 0.638608
# Minibatch 准确率: 81.2%
# 验证集准确率: 84.8%
# Minibatch loss at step 2000: 0.207914
# Minibatch 准确率: 93.8%
# 验证集准确率: 86.3%
# Minibatch loss at step 2500: 0.157246
# Minibatch 准确率: 93.8%
# 验证集准确率: 86.0%
# Minibatch loss at step 3000: 0.506121
# Minibatch 准确率: 75.0%
# 验证集准确率: 86.2%
# 测试集准确率: 92.9%

# %% [markdown]
# # 问题 2
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic LeNet5 architecture, adding Dropout, and/or adding learning rate decay.
#
# 给卷积神经网络添加dropout或学习率衰减等优化方法，测试集达到了96.2%的准确率。

# %%
batch_size = 16 # 每个批次样本大小
patch_size = 5
depth = 16 # depth的大小应该与batch_size的大小一样
num_hidden = 64
graph = tf.Graph()
beta = 0.001

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    
    layer2_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        keep_prob = tf.placeholder("float")
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        pool = tf.nn.dropout(hidden, keep_prob)
        pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        
        conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        pool = tf.nn.dropout(hidden, keep_prob)
        pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        
        shape = pool.get_shape().as_list()
        reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    regularization_1 = tf.nn.l2_loss(layer1_weights)
    regularization_2 = tf.nn.l2_loss(layer2_weights)
    regularization_3 = tf.nn.l2_loss(layer3_weights)
    regularization_4 = tf.nn.l2_loss(layer4_weights)
    regularization = regularization_1 + regularization_2 + regularization_3 + regularization_4
    loss = tf.reduce_mean(loss + beta * regularization)
    
    # Optimizer.
    global_step = tf.Variable(0)  # count the number of steps taken.
    start_learning_rate = 0.1
    learning_rate = tf.train.exponential_decay(start_learning_rate, global_step, num_steps, 0.7, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 30001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("初始化变量...")
    for step in range(num_steps):
        # Pick an offset within the training data, which has been randomized.
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        # Prepare a dictionary telling the session where to feed the minibatch.
        # The key of the dictionary is the placeholder node of the graph to be fed,
        # and the value is the numpy array to feed to it.
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 1000 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch 准确率: %.1f%%" % accuracy(predictions, batch_labels))
            print("验证集准确率: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
    print("测试集准确率: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-10-4b676db3441a>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# 初始化变量...
# Minibatch loss at step 0: 3.415812
# Minibatch 准确率: 6.2%
# 验证集准确率: 10.0%
# Minibatch loss at step 1000: 0.576732
# Minibatch 准确率: 81.2%
# 验证集准确率: 84.4%
# Minibatch loss at step 2000: 0.346226
# Minibatch 准确率: 93.8%
# 验证集准确率: 86.0%
# Minibatch loss at step 3000: 0.664854
# Minibatch 准确率: 75.0%
# 验证集准确率: 86.7%
# Minibatch loss at step 4000: 0.792451
# Minibatch 准确率: 87.5%
# 验证集准确率: 88.1%
# Minibatch loss at step 5000: 0.318054
# Minibatch 准确率: 93.8%
# 验证集准确率: 87.9%
# Minibatch loss at step 6000: 0.367250
# Minibatch 准确率: 93.8%
# 验证集准确率: 88.0%
# Minibatch loss at step 7000: 0.569449
# Minibatch 准确率: 87.5%
# 验证集准确率: 89.4%
# Minibatch loss at step 8000: 0.511075
# Minibatch 准确率: 93.8%
# 验证集准确率: 89.7%
# Minibatch loss at step 9000: 0.336807
# Minibatch 准确率: 93.8%
# 验证集准确率: 89.5%
# Minibatch loss at step 10000: 0.231130
# Minibatch 准确率: 100.0%
# 验证集准确率: 89.8%
# Minibatch loss at step 11000: 0.243333
# Minibatch 准确率: 93.8%
# 验证集准确率: 90.1%
# Minibatch loss at step 12000: 0.337737
# Minibatch 准确率: 93.8%
# 验证集准确率: 90.1%
# Minibatch loss at step 13000: 0.239488
# Minibatch 准确率: 100.0%
# 验证集准确率: 90.5%
# Minibatch loss at step 14000: 0.433656
# Minibatch 准确率: 93.8%
# 验证集准确率: 90.4%
# Minibatch loss at step 15000: 0.301268
# Minibatch 准确率: 87.5%
# 验证集准确率: 90.6%
# Minibatch loss at step 16000: 0.122826
# Minibatch 准确率: 100.0%
# 验证集准确率: 90.7%
# Minibatch loss at step 17000: 0.226908
# Minibatch 准确率: 93.8%
# 验证集准确率: 90.8%
# Minibatch loss at step 18000: 0.624701
# Minibatch 准确率: 81.2%
# 验证集准确率: 90.5%
# Minibatch loss at step 19000: 0.215347
# Minibatch 准确率: 100.0%
# 验证集准确率: 90.8%
# Minibatch loss at step 20000: 0.138437
# Minibatch 准确率: 100.0%
# 验证集准确率: 90.9%
# Minibatch loss at step 21000: 0.559726
# Minibatch 准确率: 81.2%
# 验证集准确率: 90.8%
# Minibatch loss at step 22000: 0.817680
# Minibatch 准确率: 81.2%
# 验证集准确率: 91.0%
# Minibatch loss at step 23000: 0.331183
# Minibatch 准确率: 93.8%
# 验证集准确率: 91.1%
# Minibatch loss at step 24000: 0.598828
# Minibatch 准确率: 87.5%
# 验证集准确率: 91.0%
# Minibatch loss at step 25000: 0.245343
# Minibatch 准确率: 93.8%
# 验证集准确率: 91.1%
# Minibatch loss at step 26000: 0.434723
# Minibatch 准确率: 87.5%
# 验证集准确率: 91.0%
# Minibatch loss at step 27000: 0.307894
# Minibatch 准确率: 87.5%
# 验证集准确率: 91.3%
# Minibatch loss at step 28000: 0.175164
# Minibatch 准确率: 100.0%
# 验证集准确率: 91.1%
# Minibatch loss at step 29000: 0.514861
# Minibatch 准确率: 81.2%
# 验证集准确率: 91.2%
# Minibatch loss at step 30000: 0.131257
# Minibatch 准确率: 100.0%
# 验证集准确率: 91.2%
# 测试集准确率: 96.2%
